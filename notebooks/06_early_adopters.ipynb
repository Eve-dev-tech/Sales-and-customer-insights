# %% [markdown]
# Early Adopters vs Long-term Users

# %% [markdown]
# Business question: Do customers who arrived early behave differently and generate more value than later users?

# %% [markdown]
# I will use Side-by-side Comparison
# LTV, AOV, Churn by Adopter Type

# %% [markdown]
# Early adopters are not just first
# They often become the most valuable and most loyal.
# This comparison tells us whether our early-adopter acquisition is worth protecting or whether the later majority drives more revenue

# %%
# ── 00. SETUP ────────────────────────────────────────────────────────


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from pathlib import Path

# ── 1. GLOBAL STYLE ──────────────────────────────────────────────────
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

FIGSIZE_STD   = (12, 5)   # standard wide chart
FIGSIZE_TALL  = (10, 7)   # for scatter / complex plots
FIGSIZE_PANEL = (14, 6)   # side-by-side panels
DPI           = 130

# Colour palette — consistent across all charts
PALETTE = {
    'churn_high': '#f85149',   # red  — high churn risk
    'churn_low':  '#3fb950',   # green — loyal customers
    'neutral':    '#58a6ff',   # blue  — general insight
    'accent':     '#e3b341',   # gold  — highlight
    'purple':     '#bc8cff',   # purple — secondary
}

# ── 2. LOAD DATA ─────────────────────────────────────────────────────
df = pd.read_csv('../data/customer_churn.csv')

# ── 3. DATE ENGINEERING ──────────────────────────────────────────────
df['Launch_Date']    = pd.to_datetime(df['Launch_Date'])
df['Peak_Sales_Date'] = pd.to_datetime(df['Peak_Sales_Date'])

# How many days from launch to peak performance
df['Days_to_Peak'] = (
    df['Peak_Sales_Date'] - df['Launch_Date']
).dt.days

# How long the product has been live (vs a reference "today")
REFERENCE_DATE = pd.Timestamp('2024-01-01')
df['Product_Age_Days'] = (
    REFERENCE_DATE - df['Launch_Date']
).dt.days

df['Launch_Year']  = df['Launch_Date'].dt.year
df['Launch_Month'] = df['Launch_Date'].dt.month

# ── 4. LIFECYCLE STAGE ENGINEERING ───────────────────────────────────
# Bin customers by purchase frequency into lifecycle stages
df['Lifecycle_Stage'] = pd.cut(
    df['Purchase_Frequency'],
    bins=[0, 3, 7, 12, 20],
    labels=['New', 'Developing', 'Established', 'Loyal']
)

# ── 5. CHURN RISK BANDS ──────────────────────────────────────────────
df['Churn_Risk_Band'] = pd.cut(
    df['Churn_Probability'],
    bins=[0, 0.33, 0.66, 1.0],
    labels=['Low Risk', 'Medium Risk', 'High Risk']
)

# ── 6. ADOPTER TYPE ──────────────────────────────────────────────────
# Early adopters = customers who transacted within 6 months of launch
df['Adopter_Type'] = np.where(
    df['Launch_Year'] <= 2021,
    'Early Adopter',
    'Later User'
)

# ── 7. CUSTOMER MATURITY BAND ────────────────────────────────────────
df['Maturity_Band'] = pd.cut(
    df['Lifetime_Value'],
    bins=[0, 2000, 5000, 10000],
    labels=['Early Value', 'Growth Value', 'Mature Value']
)

# ── 8. OUTPUT FOLDER ─────────────────────────────────────────────────
OUT = Path('../outputs/charts')
OUT.mkdir(parents=True, exist_ok=True)

print(f"✓ Dataset loaded: {df.shape[0]:,} rows × {df.shape[1]} cols")
print(f"✓ Output path: {OUT}")
df.head(3)
# Out:
# ✓ Dataset loaded: 10,000 rows × 23 cols
# ✓ Output path: ..\outputs\charts
#    Customer_ID   Product_ID Transaction_ID  Purchase_Frequency  \
# 0  CUST_9HOS83  PROD_IK97D1   TRANS_II1DZG                  17
# 1  CUST_AJU17N  PROD_UNN7KP   TRANS_9HJF7I                  10
# 2  CUST_11XNYF  PROD_0XEW2W   TRANS_OT96OM                   3
#
#    Average_Order_Value Most_Frequent_Category  Time_Between_Purchases  \
# 0               172.57            Electronics                      45
# 1                64.89               Clothing                       6
# 2               120.38                 Sports                      23
#
#           Region  Churn_Probability  Lifetime_Value  ...  \
# 0  South America               0.98          952.81  ...
# 1  South America               0.66         5427.51  ...
# 2           Asia               0.60         3994.80  ...
#
#   Preferred_Purchase_Times Retention_Strategy Days_to_Peak Product_Age_Days  \
# ...

# %%
# ── 06. EARLY ADOPTERS vs LONG-TERM USERS ────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(16, 5), dpi=DPI)

adopter_pal = {
    'Early Adopter': PALETTE['accent'],
    'Later User':    PALETTE['neutral']
}

# PANEL 1: LTV box plot
sns.boxplot(
    data=df, x='Adopter_Type', y='Lifetime_Value',
    palette=adopter_pal, width=0.5,
    flierprops=dict(marker='o', markersize=2, alpha=0.2),
    ax=axes[0]
)
axes[0].set_title('Lifetime Value', fontsize=13, fontweight='bold')
axes[0].set_ylabel('LTV ($)')
axes[0].yaxis.set_major_formatter(
    mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))

# PANEL 2: Average Order Value
sns.boxplot(
    data=df, x='Adopter_Type', y='Average_Order_Value',
    palette=adopter_pal, width=0.5,
    flierprops=dict(marker='o', markersize=2, alpha=0.2),
    ax=axes[1]
)
axes[1].set_title('Average Order Value', fontsize=13, fontweight='bold')
axes[1].set_ylabel('AOV ($)')
axes[1].yaxis.set_major_formatter(
    mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))

# PANEL 3: Churn probability
sns.violinplot(
    data=df, x='Adopter_Type', y='Churn_Probability',
    palette=adopter_pal, inner='quartile',
    ax=axes[2]
)
axes[2].set_title('Churn Risk Distribution', fontsize=13, fontweight='bold')
axes[2].set_ylabel('Churn Probability')
axes[2].axhline(0.7, color=PALETTE['churn_high'],
                linestyle=':', alpha=0.5, label='High-risk line')

plt.suptitle('Early Adopters vs Later Users — Value & Risk Profile',
             fontsize=15, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig(OUT / '06_early_vs_late.png', bbox_inches='tight')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11528\1975881032.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11528\1975881032.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11528\1975881032.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
